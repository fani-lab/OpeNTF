# %% [markdown]
# # What is `OpeNTF`?
# `OpeNTF` is an open-source framework hosting large-scale training datasets and canonical neural team formation models that are trained using fairness-aware and time-sensitive methods.

# %% [markdown]
# ## Quickstart on `OpeNTF`
#
# `OpeNTF` has the following required arguments:
#
# - `-data`: the path of the input datasets.
# - `-domain`: the domain the input dataset belongs in.
# - `-model`: the neural team formation models to be used in the run.
#
# As well, other optional arguments include:
# - `-attribute`: the set of our sensitive attributes (e.g., popularity).
# - `-fairness`: fairness metrics for reranking algorithms, used to minimize different bias.
# - `-np-ratio`: desired ratio of non-popular experts after reranking.
# - `-k_max`: cutoff for the reranking algorithms.
# - `-filter`: remove outliers, if needed.
# - `-future`: predict future, if needed.
# - `-exp_id`: ID of the experiment.
# - `-output`: path of the baseline output.
#
# Note that some of the optional arguments on the top uses the extensions of `OpeNTF` (e.g., `Adila`).
#
# The following is a sample run of the `OpeNTF` codebase using a toy dataset `toy.dblp.v12.json`, which is modelled after the DBLP dataset: a dataset consisting of authorship and skill information on more than 4 million Computer Science research publications. Two neural models (`feedforward` and `Bayesian`) are used in this quickstart.

# %%
# %cd src
# !python -u main.py -data ../data/raw/dblp/toy.dblp.v12.json -domain dblp -model fnn bnn -fairness det_greedy -attribute popularity
# Out:
# [WinError 2] The system cannot find the file specified: 'src'
# c:\Users\tea-n_\Documents\GitHub\OpeNTF framework\OpeNTF\src
# Loading sparse matrices from ./../data/preprocessed/dblp/toy.dblp.v12.json/teamsvecs.pkl ...
# Loading indexes pickle from ./../data/preprocessed/dblp/toy.dblp.v12.json/indexes.pkl ...
# It took 0.0019981861114501953 seconds to load from the pickles.
# It took 0.012996912002563477 seconds to load the sparse matrices.
# Running for (dataset, model): (dblp, fnn) ...
# Fold 0/2, Epoch 0/9, Minibatch 0/0, Phase train, Running Loss train 0.6056249141693115, Time 0.0507659912109375, Overall 2.9880211353302
# Fold 0/2, Epoch 0/9, Running Loss train 0.03562499495113597, Time 0.0507659912109375, Overall 2.9880211353302
# Fold 0/2, Epoch 0/9, Minibatch 0/0, Phase valid, Running Loss valid 0.5972533226013184, Time 0.05572986602783203, Overall 2.9929850101470947
# Fold 0/2, Epoch 0/9, Running Loss valid 0.06636148028903538, Time 0.05572986602783203, Overall 2.9929850101470947
# Fold 0/2, Epoch 1/9, Minibatch 0/0, Phase train, Running Loss train 0.5991436243057251, Time 0.07272839546203613, Overall 3.009983539581299
# Fold 0/2, Epoch 1/9, Running Loss train 0.035243742606219125, Time 0.07272839546203613, Overall 3.009983539581299
# Fold 0/2, Epoch 1/9, Minibatch 0/0, Phase valid, Running Loss valid 0.592308521270752, Time 0.07672905921936035, Overall 3.013984203338623
# Fold 0/2, Epoch 1/9, Running Loss valid 0.06581205791897243, Time 0.07672905921936035, Overall 3.013984203338623
# EarlyStopping counter: 1 out of 5
# Fold 0/2, Epoch 2/9, Minibatch 0/0, Phase train, Running Loss train 0.592818021774292, Time 0.08708858489990234, Overall 3.024343729019165
# Fold 0/2, Epoch 2/9, Running Loss train 0.03487164833966423, Time 0.08708858489990234, Overall 3.024343729019165
# Fold 0/2, Epoch 2/9, Minibatch 0/0, Phase valid, Running Loss valid 0.5874701738357544, Time 0.09109020233154297, Overall 3.0283453464508057
# Fold 0/2, Epoch 2/9, Running Loss valid 0.06527446375952826, Time 0.09109020233154297, Overall 3.0283453464508057
# EarlyStopping counter: 2 out of 5
# Fold 0/2, Epoch 3/9, Minibatch 0/0, Phase train, Running Loss train 0.5866307020187378, Time 0.10109424591064453, Overall 3.0383493900299072
# Fold 0/2, Epoch 3/9, Running Loss train 0.0345076883540434, Time 0.10109424591064453, Overall 3.0383493900299072
# Fold 0/2, Epoch 3/9, Minibatch 0/0, Phase valid, Running Loss valid 0.5827431082725525, Time 0.10508847236633301, Overall 3.0423436164855957
# Fold 0/2, Epoch 3/9, Running Loss valid 0.06474923425250584, Time 0.10508847236633301, Overall 3.0423436164855957
# EarlyStopping counter: 3 out of 5
# Fold 0/2, Epoch 4/9, Minibatch 0/0, Phase train, Running Loss train 0.5805637240409851, Time 0.11522793769836426, Overall 3.052483081817627
# Fold 0/2, Epoch 4/9, Running Loss train 0.034150807296528536, Time 0.11522793769836426, Overall 3.052483081817627
# Fold 0/2, Epoch 4/9, Minibatch 0/0, Phase valid, Running Loss valid 0.5781247019767761, Time 0.11822772026062012, Overall 3.055482864379883
# Fold 0/2, Epoch 4/9, Running Loss valid 0.06423607799741957, Time 0.11922717094421387, Overall 3.0564823150634766
# EarlyStopping counter: 4 out of 5
# Fold 0/2, Epoch 5/9, Minibatch 0/0, Phase train, Running Loss train 0.574617326259613, Time 0.12823057174682617, Overall 3.065485715866089
# Fold 0/2, Epoch 5/9, Running Loss train 0.03380101919174194, Time 0.12922906875610352, Overall 3.066484212875366
# Fold 0/2, Epoch 5/9, Minibatch 0/0, Phase valid, Running Loss valid 0.5736306309700012, Time 0.13222789764404297, Overall 3.0694830417633057
# Fold 0/2, Epoch 5/9, Running Loss valid 0.06373673677444458, Time 0.13222789764404297, Overall 3.0694830417633057
# EarlyStopping counter: 5 out of 5
# Early Stopping Triggered at epoch: 5
# Fold 1/2, Epoch 0/9, Minibatch 0/0, Phase train, Running Loss train 0.6933990716934204, Time 0.009009122848510742, Overall 3.0846405029296875
# Fold 1/2, Epoch 0/9, Running Loss train 0.04078818068784826, Time 0.009009122848510742, Overall 3.0846405029296875
# Fold 1/2, Epoch 0/9, Minibatch 0/0, Phase valid, Running Loss valid 0.6659319996833801, Time 0.012007474899291992, Overall 3.0876388549804688
# Fold 1/2, Epoch 0/9, Running Loss valid 0.07399244440926446, Time 0.01300811767578125, Overall 3.088639497756958
# Fold 1/2, Epoch 1/9, Minibatch 0/0, Phase train, Running Loss train 0.6839163899421692, Time 0.0290071964263916, Overall 3.1046385765075684
# Fold 1/2, Epoch 1/9, Running Loss train 0.040230375878951126, Time 0.0290071964263916, Overall 3.1046385765075684
# Fold 1/2, Epoch 1/9, Minibatch 0/0, Phase valid, Running Loss valid 0.6573002338409424, Time 0.033972978591918945, Overall 3.1096043586730957
# Fold 1/2, Epoch 1/9, Running Loss valid 0.07303335931566027, Time 0.033972978591918945, Overall 3.1096043586730957
# EarlyStopping counter: 1 out of 5
# Fold 1/2, Epoch 2/9, Minibatch 0/0, Phase train, Running Loss train 0.6747457981109619, Time 0.044973134994506836, Overall 3.1206045150756836
# Fold 1/2, Epoch 2/9, Running Loss train 0.03969092930064482, Time 0.044973134994506836, Overall 3.1206045150756836
# Fold 1/2, Epoch 2/9, Minibatch 0/0, Phase valid, Running Loss valid 0.6489450335502625, Time 0.04804110527038574, Overall 3.1236724853515625
# Fold 1/2, Epoch 2/9, Running Loss valid 0.07210500372780694, Time 0.04804110527038574, Overall 3.1236724853515625
# EarlyStopping counter: 2 out of 5
# Fold 1/2, Epoch 3/9, Minibatch 0/0, Phase train, Running Loss train 0.6658795475959778, Time 0.059162139892578125, Overall 3.134793519973755
# Fold 1/2, Epoch 3/9, Running Loss train 0.03916938515270457, Time 0.059162139892578125, Overall 3.134793519973755
# Fold 1/2, Epoch 3/9, Minibatch 0/0, Phase valid, Running Loss valid 0.640863835811615, Time 0.06316494941711426, Overall 3.138796329498291
# Fold 1/2, Epoch 3/9, Running Loss valid 0.07120709286795722, Time 0.06316494941711426, Overall 3.138796329498291
# EarlyStopping counter: 3 out of 5
# Fold 1/2, Epoch 4/9, Minibatch 0/0, Phase train, Running Loss train 0.6573038697242737, Time 0.07298898696899414, Overall 3.148620367050171
# Fold 1/2, Epoch 4/9, Running Loss train 0.03866493351319257, Time 0.07298898696899414, Overall 3.148620367050171
# Fold 1/2, Epoch 4/9, Minibatch 0/0, Phase valid, Running Loss valid 0.6330206394195557, Time 0.0762319564819336, Overall 3.1518633365631104
# Fold 1/2, Epoch 4/9, Running Loss valid 0.07033562660217285, Time 0.0762319564819336, Overall 3.1518633365631104
# EarlyStopping counter: 4 out of 5
# Fold 1/2, Epoch 5/9, Minibatch 0/0, Phase train, Running Loss train 0.6490036845207214, Time 0.08623027801513672, Overall 3.1618616580963135
# Fold 1/2, Epoch 5/9, Running Loss train 0.03817668732474832, Time 0.08723044395446777, Overall 3.1628618240356445
# Fold 1/2, Epoch 5/9, Minibatch 0/0, Phase valid, Running Loss valid 0.6254642009735107, Time 0.09022855758666992, Overall 3.1658599376678467
# Fold 1/2, Epoch 5/9, Running Loss valid 0.06949602233039008, Time 0.09022855758666992, Overall 3.1658599376678467
# EarlyStopping counter: 5 out of 5
# Early Stopping Triggered at epoch: 5
# Fold 2/2, Epoch 0/9, Minibatch 0/0, Phase train, Running Loss train 0.6977599263191223, Time 0.009129047393798828, Overall 3.1809446811676025
# Fold 2/2, Epoch 0/9, Running Loss train 0.03876444035106235, Time 0.009129047393798828, Overall 3.1809446811676025
# Fold 2/2, Epoch 0/9, Minibatch 0/0, Phase valid, Running Loss valid 0.7054514288902283, Time 0.01214146614074707, Overall 3.183957099914551
# Fold 2/2, Epoch 0/9, Running Loss valid 0.08818142861127853, Time 0.01214146614074707, Overall 3.183957099914551
# Fold 2/2, Epoch 1/9, Minibatch 0/0, Phase train, Running Loss train 0.687987744808197, Time 0.025124788284301758, Overall 3.1969404220581055
# Fold 2/2, Epoch 1/9, Running Loss train 0.038221541378233165, Time 0.025124788284301758, Overall 3.1969404220581055
# Fold 2/2, Epoch 1/9, Minibatch 0/0, Phase valid, Running Loss valid 0.6971001029014587, Time 0.02812790870666504, Overall 3.1999435424804688
# Fold 2/2, Epoch 1/9, Running Loss valid 0.08713751286268234, Time 0.02812790870666504, Overall 3.1999435424804688
# EarlyStopping counter: 1 out of 5
# Fold 2/2, Epoch 2/9, Minibatch 0/0, Phase train, Running Loss train 0.678523600101471, Time 0.03809022903442383, Overall 3.2099058628082275
# Fold 2/2, Epoch 2/9, Running Loss train 0.03769575556119283, Time 0.03809022903442383, Overall 3.2099058628082275
# Fold 2/2, Epoch 2/9, Minibatch 0/0, Phase valid, Running Loss valid 0.6890474557876587, Time 0.04112529754638672, Overall 3.2129409313201904
# Fold 2/2, Epoch 2/9, Running Loss valid 0.08613093197345734, Time 0.04212832450866699, Overall 3.2139439582824707
# EarlyStopping counter: 2 out of 5
# Fold 2/2, Epoch 3/9, Minibatch 0/0, Phase train, Running Loss train 0.6693738698959351, Time 0.05153536796569824, Overall 3.223351001739502
# Fold 2/2, Epoch 3/9, Running Loss train 0.037187437216440834, Time 0.05153536796569824, Overall 3.223351001739502
# Fold 2/2, Epoch 3/9, Minibatch 0/0, Phase valid, Running Loss valid 0.6812991499900818, Time 0.055664777755737305, Overall 3.227480411529541
# Fold 2/2, Epoch 3/9, Running Loss valid 0.08516239374876022, Time 0.055664777755737305, Overall 3.227480411529541
# EarlyStopping counter: 3 out of 5
# Fold 2/2, Epoch 4/9, Minibatch 0/0, Phase train, Running Loss train 0.6605099439620972, Time 0.06554150581359863, Overall 3.2373571395874023
# Fold 2/2, Epoch 4/9, Running Loss train 0.036694996886783175, Time 0.06554150581359863, Overall 3.2383627891540527
# Fold 2/2, Epoch 4/9, Minibatch 0/0, Phase valid, Running Loss valid 0.6738382577896118, Time 0.06960129737854004, Overall 3.2414169311523438
# Fold 2/2, Epoch 4/9, Running Loss valid 0.08422978222370148, Time 0.06960129737854004, Overall 3.2414169311523438
# EarlyStopping counter: 4 out of 5
# Fold 2/2, Epoch 5/9, Minibatch 0/0, Phase train, Running Loss train 0.6519139409065247, Time 0.07919692993164062, Overall 3.2510125637054443
# Fold 2/2, Epoch 5/9, Running Loss train 0.036217441161473594, Time 0.08025479316711426, Overall 3.252070426940918
# Fold 2/2, Epoch 5/9, Minibatch 0/0, Phase valid, Running Loss valid 0.6666646599769592, Time 0.0832357406616211, Overall 3.255051374435425
# Fold 2/2, Epoch 5/9, Running Loss valid 0.0833330824971199, Time 0.0832357406616211, Overall 3.255051374435425
# EarlyStopping counter: 5 out of 5
# Early Stopping Triggered at epoch: 5
# It took 3.2590525150299072 to train the model.
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Building pytrec_eval input for 5 instances ...
# Evaluating {'map_cut_2,5,10', 'ndcg_cut_2,5,10', 'P_2,5,10', 'recall_2,5,10'} ...
# Averaging ...
# Building pytrec_eval input for 5 instances ...
# Evaluating {'map_cut_2,5,10', 'ndcg_cut_2,5,10', 'P_2,5,10', 'recall_2,5,10'} ...
# Averaging ...
# Building pytrec_eval input for 5 instances ...
# Evaluating {'map_cut_2,5,10', 'ndcg_cut_2,5,10', 'P_2,5,10', 'recall_2,5,10'} ...
# Averaging ...
# ####################################################################################################
# Reranking for the baseline ../output/toy.dblp.v12.json/fnn/t31.s10.m13.l[100].lr0.001.b128.e10.nns3.nsnone.lossSL/t31.s10.m13.l[100].lr0.001.b128.e10.nns3.nsnone.lossSL/f0.test.pred ...
# Loading popularity labels ...
# Loading reranking results ...
# Loading fairness evaluation results before and after reranking ...
# Loading fairness results failed! Evaluating fairness metric {'ndkl'} ...
# Loading utility metric evaluation results before and after reranking ...
# Pipeline for the baseline ../output/toy.dblp.v12.json/fnn/t31.s10.m13.l[100].lr0.001.b128.e10.nns3.nsnone.lossSL/t31.s10.m13.l[100].lr0.001.b128.e10.nns3.nsnone.lossSL/f0.test.pred completed by <_MainProcess name='MainProcess' parent=None started>! 0.06149601936340332
# ####################################################################################################
# ####################################################################################################
# Reranking for the baseline ../output/toy.dblp.v12.json/fnn/t31.s10.m13.l[100].lr0.001.b128.e10.nns3.nsnone.lossSL/t31.s10.m13.l[100].lr0.001.b128.e10.nns3.nsnone.lossSL/f1.test.pred ...
# Loading popularity labels ...
# Loading reranking results ...
# Loading fairness evaluation results before and after reranking ...
# Loading fairness results failed! Evaluating fairness metric {'ndkl'} ...
# Loading utility metric evaluation results before and after reranking ...
# Pipeline for the baseline ../output/toy.dblp.v12.json/fnn/t31.s10.m13.l[100].lr0.001.b128.e10.nns3.nsnone.lossSL/t31.s10.m13.l[100].lr0.001.b128.e10.nns3.nsnone.lossSL/f1.test.pred completed by <_MainProcess name='MainProcess' parent=None started>! 0.040962934494018555
# ####################################################################################################
# ####################################################################################################
# Reranking for the baseline ../output/toy.dblp.v12.json/fnn/t31.s10.m13.l[100].lr0.001.b128.e10.nns3.nsnone.lossSL/t31.s10.m13.l[100].lr0.001.b128.e10.nns3.nsnone.lossSL/f2.test.pred ...
# Loading popularity labels ...
# Loading reranking results ...
# Loading fairness evaluation results before and after reranking ...
# Loading fairness results failed! Evaluating fairness metric {'ndkl'} ...
# Loading utility metric evaluation results before and after reranking ...
# Pipeline for the baseline ../output/toy.dblp.v12.json/fnn/t31.s10.m13.l[100].lr0.001.b128.e10.nns3.nsnone.lossSL/t31.s10.m13.l[100].lr0.001.b128.e10.nns3.nsnone.lossSL/f2.test.pred completed by <_MainProcess name='MainProcess' parent=None started>! 0.04145026206970215
# ####################################################################################################
# Running for (dataset, model): (dblp, bnn) ...
# Fold 0/2, Epoch 0/4, Minibatch 0/0, Phase train, Running Loss train 9.701826095581055, Time 0.018190622329711914, Overall 0.021055936813354492
# Fold 0/2, Epoch 0/4, Running Loss train 0.5706956526812386, Time 0.018190622329711914, Overall 0.021055936813354492
# Fold 0/2, Epoch 0/4, Minibatch 0/0, Phase valid, Running Loss valid 6.872168064117432, Time 0.027338266372680664, Overall 0.030203580856323242
# Fold 0/2, Epoch 0/4, Running Loss valid 0.7635742293463813, Time 0.027338266372680664, Overall 0.030203580856323242
# Fold 0/2, Epoch 1/4, Minibatch 0/0, Phase train, Running Loss train 7.5233869552612305, Time 0.04839587211608887, Overall 0.051261186599731445
# Fold 0/2, Epoch 1/4, Running Loss train 0.4425521738388959, Time 0.04839587211608887, Overall 0.051261186599731445
# Fold 0/2, Epoch 1/4, Minibatch 0/0, Phase valid, Running Loss valid 5.3721466064453125, Time 0.05639481544494629, Overall 0.05926012992858887
# Fold 0/2, Epoch 1/4, Running Loss valid 0.5969051784939237, Time 0.05739259719848633, Overall 0.060257911682128906
# Fold 0/2, Epoch 2/4, Minibatch 0/0, Phase train, Running Loss train 8.192795753479004, Time 0.0774836540222168, Overall 0.08034896850585938
# Fold 0/2, Epoch 2/4, Running Loss train 0.48192916196935315, Time 0.0774836540222168, Overall 0.08034896850585938
# Fold 0/2, Epoch 2/4, Minibatch 0/0, Phase valid, Running Loss valid 3.359665632247925, Time 0.0865178108215332, Overall 0.08938312530517578
# Fold 0/2, Epoch 2/4, Running Loss valid 0.37329618136088055, Time 0.0865178108215332, Overall 0.08938312530517578
# Fold 0/2, Epoch 3/4, Minibatch 0/0, Phase train, Running Loss train 8.646369934082031, Time 0.1096503734588623, Overall 0.11251568794250488
# Fold 0/2, Epoch 3/4, Running Loss train 0.5086099961224724, Time 0.1096503734588623, Overall 0.11251568794250488
# Fold 0/2, Epoch 3/4, Minibatch 0/0, Phase valid, Running Loss valid 10.325803756713867, Time 0.11765170097351074, Overall 0.12051701545715332
# Fold 0/2, Epoch 3/4, Running Loss valid 1.147311528523763, Time 0.11868834495544434, Overall 0.12155365943908691
# EarlyStopping counter: 1 out of 5
# Fold 0/2, Epoch 4/4, Minibatch 0/0, Phase train, Running Loss train 8.802574157714844, Time 0.13765859603881836, Overall 0.14052391052246094
# Fold 0/2, Epoch 4/4, Running Loss train 0.517798479865579, Time 0.138657808303833, Overall 0.14152312278747559
# Fold 0/2, Epoch 4/4, Minibatch 0/0, Phase valid, Running Loss valid 6.550690650939941, Time 0.14665746688842773, Overall 0.1495227813720703
# Fold 0/2, Epoch 4/4, Running Loss valid 0.7278545167711046, Time 0.14665746688842773, Overall 0.1495227813720703
# EarlyStopping counter: 2 out of 5
# Fold 1/2, Epoch 0/4, Minibatch 0/0, Phase train, Running Loss train 8.19212818145752, Time 0.016184568405151367, Overall 0.17570805549621582
# Fold 1/2, Epoch 0/4, Running Loss train 0.48188989302691293, Time 0.016184568405151367, Overall 0.17570805549621582
# Fold 1/2, Epoch 0/4, Minibatch 0/0, Phase valid, Running Loss valid 10.479596138000488, Time 0.02418231964111328, Overall 0.18370580673217773
# Fold 1/2, Epoch 0/4, Running Loss valid 1.1643995708889432, Time 0.025183677673339844, Overall 0.1847071647644043
# Fold 1/2, Epoch 1/4, Minibatch 0/0, Phase train, Running Loss train 7.664950370788574, Time 0.04637622833251953, Overall 0.20589971542358398
# Fold 1/2, Epoch 1/4, Running Loss train 0.45087943357579846, Time 0.04637622833251953, Overall 0.20589971542358398
# Fold 1/2, Epoch 1/4, Minibatch 0/0, Phase valid, Running Loss valid 5.143964767456055, Time 0.05441546440124512, Overall 0.21393895149230957
# Fold 1/2, Epoch 1/4, Running Loss valid 0.5715516408284506, Time 0.05441546440124512, Overall 0.21393895149230957
# Fold 1/2, Epoch 2/4, Minibatch 0/0, Phase train, Running Loss train 7.0461907386779785, Time 0.07616400718688965, Overall 0.2356874942779541
# Fold 1/2, Epoch 2/4, Running Loss train 0.41448180815752816, Time 0.07616400718688965, Overall 0.2356874942779541
# Fold 1/2, Epoch 2/4, Minibatch 0/0, Phase valid, Running Loss valid 5.6814775466918945, Time 0.0841226577758789, Overall 0.24364614486694336
# Fold 1/2, Epoch 2/4, Running Loss valid 0.6312752829657661, Time 0.0841226577758789, Overall 0.24364614486694336
# EarlyStopping counter: 1 out of 5
# Fold 1/2, Epoch 3/4, Minibatch 0/0, Phase train, Running Loss train 9.323131561279297, Time 0.10512852668762207, Overall 0.2646520137786865
# Fold 1/2, Epoch 3/4, Running Loss train 0.5484195036046645, Time 0.10512852668762207, Overall 0.2646520137786865
# Fold 1/2, Epoch 3/4, Minibatch 0/0, Phase valid, Running Loss valid 5.848703384399414, Time 0.11430501937866211, Overall 0.27382850646972656
# Fold 1/2, Epoch 3/4, Running Loss valid 0.6498559315999349, Time 0.11430501937866211, Overall 0.27382850646972656
# EarlyStopping counter: 2 out of 5
# Fold 1/2, Epoch 4/4, Minibatch 0/0, Phase train, Running Loss train 8.630220413208008, Time 0.13330769538879395, Overall 0.2928311824798584
# Fold 1/2, Epoch 4/4, Running Loss train 0.5076600243063534, Time 0.13330769538879395, Overall 0.2928311824798584
# Fold 1/2, Epoch 4/4, Minibatch 0/0, Phase valid, Running Loss valid 6.053482532501221, Time 0.1417984962463379, Overall 0.30132198333740234
# Fold 1/2, Epoch 4/4, Running Loss valid 0.6726091702779134, Time 0.1417984962463379, Overall 0.30132198333740234
# EarlyStopping counter: 3 out of 5
# Fold 2/2, Epoch 0/4, Minibatch 0/0, Phase train, Running Loss train 13.120939254760742, Time 0.016001462936401367, Overall 0.32532310485839844
# Fold 2/2, Epoch 0/4, Running Loss train 0.7289410697089301, Time 0.016962766647338867, Overall 0.32628440856933594
# Fold 2/2, Epoch 0/4, Minibatch 0/0, Phase valid, Running Loss valid 7.2940826416015625, Time 0.02499985694885254, Overall 0.3343214988708496
# Fold 2/2, Epoch 0/4, Running Loss valid 0.9117603302001953, Time 0.02499985694885254, Overall 0.3343214988708496
# Fold 2/2, Epoch 1/4, Minibatch 0/0, Phase train, Running Loss train 6.706620693206787, Time 0.04700016975402832, Overall 0.3563218116760254
# Fold 2/2, Epoch 1/4, Running Loss train 0.3725900385114882, Time 0.04700016975402832, Overall 0.3563218116760254
# Fold 2/2, Epoch 1/4, Minibatch 0/0, Phase valid, Running Loss valid 5.9946818351745605, Time 0.05800151824951172, Overall 0.3673231601715088
# Fold 2/2, Epoch 1/4, Running Loss valid 0.7493352293968201, Time 0.05800151824951172, Overall 0.3673231601715088
# Fold 2/2, Epoch 2/4, Minibatch 0/0, Phase train, Running Loss train 6.208798408508301, Time 0.07899999618530273, Overall 0.3883216381072998
# Fold 2/2, Epoch 2/4, Running Loss train 0.34493324491712785, Time 0.07899999618530273, Overall 0.3883216381072998
# Fold 2/2, Epoch 2/4, Minibatch 0/0, Phase valid, Running Loss valid 6.477299213409424, Time 0.0873870849609375, Overall 0.39670872688293457
# Fold 2/2, Epoch 2/4, Running Loss valid 0.809662401676178, Time 0.08847355842590332, Overall 0.3977952003479004
# EarlyStopping counter: 1 out of 5
# Fold 2/2, Epoch 3/4, Minibatch 0/0, Phase train, Running Loss train 6.142394065856934, Time 0.10651612281799316, Overall 0.41583776473999023
# Fold 2/2, Epoch 3/4, Running Loss train 0.34124411476982963, Time 0.10651612281799316, Overall 0.41583776473999023
# Fold 2/2, Epoch 3/4, Minibatch 0/0, Phase valid, Running Loss valid 6.238161563873291, Time 0.11433148384094238, Overall 0.42365312576293945
# Fold 2/2, Epoch 3/4, Running Loss valid 0.7797701954841614, Time 0.11433148384094238, Overall 0.42365312576293945
# EarlyStopping counter: 2 out of 5
# Fold 2/2, Epoch 4/4, Minibatch 0/0, Phase train, Running Loss train 5.8609395027160645, Time 0.13337326049804688, Overall 0.44269490242004395
# Fold 2/2, Epoch 4/4, Running Loss train 0.3256077501508925, Time 0.13337326049804688, Overall 0.44269490242004395
# Fold 2/2, Epoch 4/4, Minibatch 0/0, Phase valid, Running Loss valid 6.935448169708252, Time 0.14133477210998535, Overall 0.4506564140319824
# Fold 2/2, Epoch 4/4, Running Loss valid 0.8669310212135315, Time 0.14133477210998535, Overall 0.4506564140319824
# EarlyStopping counter: 3 out of 5
# It took 0.4577000141143799 to train the model.
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Building pytrec_eval input for 5 instances ...
# Evaluating {'map_cut_2,5,10', 'ndcg_cut_2,5,10', 'P_2,5,10', 'recall_2,5,10'} ...
# Averaging ...
# Building pytrec_eval input for 5 instances ...
# Evaluating {'map_cut_2,5,10', 'ndcg_cut_2,5,10', 'P_2,5,10', 'recall_2,5,10'} ...
# Averaging ...
# Building pytrec_eval input for 5 instances ...
# Evaluating {'map_cut_2,5,10', 'ndcg_cut_2,5,10', 'P_2,5,10', 'recall_2,5,10'} ...
# Averaging ...
# ####################################################################################################
# Reranking for the baseline ../output/toy.dblp.v12.json/bnn/t31.s10.m13.l[128].lr0.1.b128.e5.nns3.nsunigram_b.s1.lossSL/t31.s10.m13.l[128].lr0.1.b128.e5.nns3.nsunigram_b.s1.lossSL/f0.test.pred ...
# Loading popularity labels ...
# Loading reranking results ...
# Loading fairness evaluation results before and after reranking ...
# Loading fairness results failed! Evaluating fairness metric {'ndkl'} ...
# Loading utility metric evaluation results before and after reranking ...
# Pipeline for the baseline ../output/toy.dblp.v12.json/bnn/t31.s10.m13.l[128].lr0.1.b128.e5.nns3.nsunigram_b.s1.lossSL/t31.s10.m13.l[128].lr0.1.b128.e5.nns3.nsunigram_b.s1.lossSL/f0.test.pred completed by <_MainProcess name='MainProcess' parent=None started>! 0.04403567314147949
# ####################################################################################################
# ####################################################################################################
# Reranking for the baseline ../output/toy.dblp.v12.json/bnn/t31.s10.m13.l[128].lr0.1.b128.e5.nns3.nsunigram_b.s1.lossSL/t31.s10.m13.l[128].lr0.1.b128.e5.nns3.nsunigram_b.s1.lossSL/f1.test.pred ...
# Loading popularity labels ...
# Loading reranking results ...
# Loading fairness evaluation results before and after reranking ...
# Loading fairness results failed! Evaluating fairness metric {'ndkl'} ...
# Loading utility metric evaluation results before and after reranking ...
# Pipeline for the baseline ../output/toy.dblp.v12.json/bnn/t31.s10.m13.l[128].lr0.1.b128.e5.nns3.nsunigram_b.s1.lossSL/t31.s10.m13.l[128].lr0.1.b128.e5.nns3.nsunigram_b.s1.lossSL/f1.test.pred completed by <_MainProcess name='MainProcess' parent=None started>! 0.041002511978149414
# ####################################################################################################
# ####################################################################################################
# Reranking for the baseline ../output/toy.dblp.v12.json/bnn/t31.s10.m13.l[128].lr0.1.b128.e5.nns3.nsunigram_b.s1.lossSL/t31.s10.m13.l[128].lr0.1.b128.e5.nns3.nsunigram_b.s1.lossSL/f2.test.pred ...
# Loading popularity labels ...
# Loading reranking results ...
# Loading fairness evaluation results before and after reranking ...
# Loading fairness results failed! Evaluating fairness metric {'ndkl'} ...
# Loading utility metric evaluation results before and after reranking ...
# Pipeline for the baseline ../output/toy.dblp.v12.json/bnn/t31.s10.m13.l[128].lr0.1.b128.e5.nns3.nsunigram_b.s1.lossSL/t31.s10.m13.l[128].lr0.1.b128.e5.nns3.nsunigram_b.s1.lossSL/f2.test.pred completed by <_MainProcess name='MainProcess' parent=None started>! 0.0410001277923584
# ####################################################################################################
# c:\Users\tea-n_\anaconda3\envs\opentf\lib\site-packages\torch\optim\lr_scheduler.py:28: UserWarning: The verbose parameter is deprecated. Please use get_last_lr() to access the learning rate.
#   warnings.warn("The verbose parameter is deprecated. Please use get_last_lr() "
#
#   0%|          | 0/5 [00:00<?, ?it/s]
# 100%|██████████| 5/5 [00:00<?, ?it/s]
#
#   0%|          | 0/5 [00:00<?, ?it/s]
# 100%|██████████| 5/5 [00:00<00:00, 4808.88it/s]
#
#   0%|          | 0/5 [00:00<?, ?it/s]
# 100%|██████████| 5/5 [00:00<?, ?it/s]
#
#   0%|          | 0/5 [00:00<?, ?it/s]
# 100%|██████████| 5/5 [00:00<00:00, 2499.59it/s]
#
#   0%|          | 0/5 [00:00<?, ?it/s]
# 100%|██████████| 5/5 [00:00<?, ?it/s]
#
#   0%|          | 0/5 [00:00<?, ?it/s]
# 100%|██████████| 5/5 [00:00<00:00, 5006.33it/s]
# c:\Users\tea-n_\anaconda3\envs\opentf\lib\site-packages\torch\optim\lr_scheduler.py:28: UserWarning: The verbose parameter is deprecated. Please use get_last_lr() to access the learning rate.
#   warnings.warn("The verbose parameter is deprecated. Please use get_last_lr() "
#
#   0%|          | 0/5 [00:00<?, ?it/s]
# 100%|██████████| 5/5 [00:00<?, ?it/s]
#
#   0%|          | 0/5 [00:00<?, ?it/s]
# 100%|██████████| 5/5 [00:00<00:00, 4988.47it/s]
#
#   0%|          | 0/5 [00:00<?, ?it/s]
# 100%|██████████| 5/5 [00:00<?, ?it/s]
#
#   0%|          | 0/5 [00:00<?, ?it/s]
# 100%|██████████| 5/5 [00:00<00:00, 5003.94it/s]
#
#   0%|          | 0/5 [00:00<?, ?it/s]
# 100%|██████████| 5/5 [00:00<?, ?it/s]
#
#   0%|          | 0/5 [00:00<?, ?it/s]
# 100%|██████████| 5/5 [00:00<00:00, 3857.90it/s]

# %% [markdown]
# ## Setting Hyperparameters
# `OpeNTF`'s codebase offers the following hyperparameter to be set for each neural team formation methods:
#
# ### `model`
# - Contains the baseline hyperparameters in the form of `'model-name' : { params }`, which allows the models to be integrated into the baseline with their unique parameters.
# - Allows the customization of which stages of the system to be executed through `cmd`.
# - Contains other training parameter for the models (e.g., temporal).
#
# ### `data`
# - Contains parameters for manipulating datasets, including dataset filters (e.g., minimum team size) and bucket size for sparse matrix parallel generation.
#
# ### `fair`
# - Contains parameters for the fairness metrics used in consideration during team formation.
#
# A snippet of the parameters used in `param.py` is displayed as follows:

# %%
import random
import torch
import numpy as np

random.seed(0)
torch.manual_seed(0)
torch.cuda.manual_seed_all(0)

np.random.seed(0)

settings = {
    'model':{
        'baseline': {
            'random': {
                'b': 128
            },
            'fnn':{
                'l': [100],  # list of number of nodes in each layer
                'lr': 0.001,  # learning rate
                'b': 128,  # batch size
                'e': 10,  # epoch
                'nns': 3,  # number of negative samples
                'ns': 'none',  # 'none', 'uniform', 'unigram', 'unigram_b'
                'loss': 'SL',  # 'SL'-> superloss, 'DP' -> Data Parameters, 'normal' -> Binary Cross Entropy
            },
            'bnn':{
                'l': [128],  # list of number of nodes in each layer
                'lr': 0.1,  # learning rate
                'b': 128,  # batch size
                'e': 5,  # epoch
                'nns': 3,  # number of negative samples
                'ns': 'unigram_b',  # 'uniform', 'unigram', 'unigram_b'
                's': 1,  # # sample_elbo for bnn
                'loss': 'SL',  # 'SL'-> superloss, 'DP' -> Data Parameters, 'normal' -> Binary Cross Entropy
            },
        },
        'cmd': ['train', 'test', 'eval', 'fair'],  # 'train', 'test', 'eval', 'plot', 'agg', 'fair'
        'nfolds': 3,
        'train_test_split': 0.85,
        'step_ahead': 2,#for now, it means that whatever are in the last [step_ahead] time interval will be the test set!
    },
    'data':{
        'domain': {
            'dblp':{},
            'uspt':{},
            'imdb':{},
        },
        'location_type': 'country', #should be one of 'city', 'state', 'country' and represents the location of members in teams (not the location of teams)
        'filter': {
            'min_nteam': 5,
            'min_team_size': 2,
        },
        'parallel': 1,
        'ncore': 0,# <= 0 for all
        'bucket_size': 1000
    },
    'fair': {'np_ratio': None,
              'fairness': ['det_greedy',],
              'k_max': None,
              'fairness_metrics': {'ndkl'},
              'utility_metrics': {'map_cut_2,5,10'},
              'eq_op': False,
              'mode': 0,
              'core': -1,
              'attribute': ['gender', 'popularity']},
}

# %% [markdown]
# ## Structure and Inheritance
#
# ### Dataset Structure
# <p align="center"><img src='./src/cmn/dataset_hierarchy.png' width="500" ></p>
#
# To integrate a new dataset into the baseline, follow the structure of the `team` class. Additional fields can be added, like its derived classes. Ideally, only the `read_data()` function should be overriden.

# %% [raw]
# [
#   {
#     "id": 1,
#     "reviewers": [
#       { "name": "Ada", "id": 1, "expertise": "Multimedia mining" },
#       { "name": "Bob", "id": 11, "expertise": "Image Captioning" },
#       { "name": "Cameron", "id": 12, "expertise": "Image Classification" }
#     ],
#     "fos": ["Image Captioning"],
#     "title": "A Comprehensive Review of Domain-specific Image Captioning",
#     "year": 2000
#   },
#   {
#     "id": 2,
#     "reviewers": [
#       { "name": "Ada", "id": 1, "expertise": "Multimedia mining" },
#       { "name": "David", "id": 9, "expertise": "Video Classification" },
#       { "name": "Cameron", "id": 12, "expertise": "Image Classification" }
#     ],
#     "fos": ["Machine Learning", "Image Segmentation"],
#     "title": "A methodology for the physically accurate visualisation of medical imaging",
#     "year": 1999
#   }
# ]

# %%
import json
from cmn.member import Member
from cmn.team import Team

class Review(Team):
    def _init_(self, id, title, year, fos, reviewers):
        super().__init__(id, reviewers, fos, year)
        self.title = title
    
    @staticmethod
    def read_data(datapath, output, index, filter, settings):
        try:
            return super(Review, Review).load_data(output, index)
        except (FileNotFoundError, EOFError) as e:
            print(f"Pickles not found! Reading raw data from {datapath} (progress in bytes) ...")
            teams = {}; candidates = {}

            with open(datapath, "r", encoding='utf-8') as jf:
                for line in jf:
                    try:
                        if not line: break
                        jsonline = json.loads(line.lower().lstrip(","))
                        id = jsonline['id']

                        # a team must have some match of skills and members
                        try: reviewers = jsonline['reviewers']
                        except: continue
                        try: fos = jsonline['fos']
                        except: continue

                        title = jsonline['title']
                        year = jsonline['year']

                        members = []
                        for reviewer in reviewers:
                            member_id = reviewer['id']
                            member_name = reviewer['name'].replace(" ", "_")
                            # candidate is the full list of all experts across teams
                            if (idname := f'{member_id}_{member_name}') not in candidates:
                                candidates[idname] = Member(member_id, member_name)
                                candidates[idname].skills.update(set(reviewer['expertise']))
                            members.append(candidates[idname])
                            
                        team = Review(id, title, year, fos, members)
                        teams[team.id] = team
                    except json.JSONDecodeError as e:  # ideally should happen only for the last line ']'
                        print(f'JSONDecodeError: There has been error in loading json line `{line}`!\n{e}')
                        continue
                    except Exception as e:
                        raise e
            return super(Review, Review).read_data(teams, output, filter, settings)
        except Exception as e: raise e

# %% [markdown]
# ### Model Structure
# <img src="./new-class-diagram.png" height=400px />
#
# To integrate a new model into the baseline, follow the `Ntf` class. Ideally, only the `learn()` method should be overriden, with `eval()` remaining the same for fair comparison.

# %%
from sklearn.neural_network import MLPClassifier
from mdl.ntf import Ntf
import pickle

class Random(Ntf):
    def __init__(self):
        super(Random, self).__init__()
    
    def init(self):
        self.model = MLPClassifier() # empty network
        return self

    def learn(self, splits, indexes, vecs, params, prev_model, output):
        # splits, vecs, and indexes are components of the preprocessed data
        # params come from param.py

        for foldidx in splits['folds'].keys():
            self.init()
            with open(f"{output}/state_dict_model.f{foldidx}.pt","wb") as f: pickle.dump(self.model,f)

# %% [markdown]
# # Additional Resources
# - [`OpeNTF` codebase](https://github.com/fani-lab/OpeNTF/tree/main)
# - [`Adila` codebase](https://github.com/fani-lab/adila)
# - [`vivaFemme` codebase](https://github.com/fani-lab/OpeNTF/tree/vivaFemme)
# - [Streaming Training Strategy codebase](https://github.com/fani-lab/OpeNTF/tree/ecir24)
# - [Tutorial Website and Materials](https://fani-lab.github.io/OpeNTF/tutorial/umap24/)
#     - [`OpeNTF` paper](https://doi.org/10.1145/3511808.3557526)
#     - [`Adila` paper](https://doi.org/10.1007/978-3-031-37249-0_9)
#     - [`vivaFemme` paper](https://hosseinfani.github.io/res/papers/2024_BIAS_SIGIR_vivaFemme_Mitigating_Gender_Bias_in_Neural_Team_Recommendation_via_Female-Advocate_Loss_Regularization.pdf)
#     - [Streaming Training Strategy paper](https://link.springer.com/chapter/10.1007/978-3-031-56027-9_20)
#
# <img src="./qr-code.png" height=300px />
